# %%
pip install tensorflow keras_cv --upgrade

# %%
import time
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Goodrich Okoro\Documents\Hamoye\GEN AI\kerascv.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Goodrich%20Okoro/Documents/Hamoye/GEN%20AI/kerascv.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import time
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Goodrich%20Okoro/Documents/Hamoye/GEN%20AI/kerascv.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import keras_cv
#       <a href='vscode-notebook-cell:/c%3A/Users/Goodrich%20Okoro/Documents/Hamoye/GEN%20AI/kerascv.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from tensorflow import keras
#       <a href='vscode-notebook-cell:/c%3A/Users/Goodrich%20Okoro/Documents/Hamoye/GEN%20AI/kerascv.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> import matplotlib.pyplot as plt
#
# File c:\Users\Goodrich Okoro\anaconda3\lib\site-packages\keras_cv\__init__.py:8
# ...
